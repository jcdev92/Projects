# %%
import pandas as pd
import sys

# %%
# !{sys.executable} -m pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /home/gordo/anaconda3/envs/betaProjects/lib/python3.10/site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /home/gordo/anaconda3/envs/betaProjects/lib/python3.10/site-packages (from openpyxl) (1.1.0)

# %%
df_table_2 = pd.read_csv('./parte4.csv')

# %%
for z in range(50):
    for i in range(50):
        try:
            df_table_2.drop(f'external_emails/{z}/sources/{i}/ref', axis=1, inplace=True)
            df_table_2.drop(f'external_emails/{z}/sources/{i}/extracted_on', axis=1, inplace=True)
            df_table_2.drop(f'external_emails/{z}/sources/{i}/updated_on', axis=1, inplace=True)
        except KeyError:
            continue

# %%
for z in range(50):
    for i in range(50):
        try:
            df_table_2.drop(f'phones/{z}/sources/{i}/ref', axis=1, inplace=True)
            df_table_2.drop(f'phones/{z}/sources/{i}/extracted_on', axis=1, inplace=True)
            df_table_2.drop(f'phones/{z}/sources/{i}/updated_on', axis=1, inplace=True)
        except KeyError:
            continue

# %%
for z in range(50):
    for i in range(50):
        try:
            df_table_2.drop(f'emails/{z}/sources/{i}/ref', axis=1, inplace=True)
            df_table_2.drop(f'emails/{z}/sources/{i}/extracted_on', axis=1, inplace=True)
            df_table_2.drop(f'emails/{z}/sources/{i}/updated_on', axis=1, inplace=True)
        except KeyError:
            continue

# %%
df_table_2.drop('site_data/description', axis=1, inplace=True)
df_table_2.drop('site_data/keywords', axis=1, inplace=True)
df_table_2.drop('site_data/title', axis=1, inplace=True)

# %%
df_table_2
# Out:
#                                                 query  \
# 0   https://locations.mcalistersdeli.com/tx/dallas...
# 1   https://www.landmarkrestodallas.com/the-librar...
# 2   https://locations.jimmyjohns.com/tx/dallas/san...
# 3                 https://www.mychocolatesecrets.com/
# 4   https://www.starbucks.com/store-locator/store/...
# 5   https://www.starbucks.com/store-locator/store/...
# 6   https://www.starbucks.com/store-locator/store/...
# 7                           http://www.pekersbar.com/
# 8                        http://lalalandkindcafe.com/
# 9                       https://www.mrmissterdtx.com/
# 10                          http://www.jrsdallas.com/
# 11                              http://www.sevys.com/
# 12                     http://ilbraccorestaurant.com/
# 13            http://rd-kitchen.com/locations/dallas/
# 14                          http://www.mlcdallas.com/
# 15                          http://hudsonhousehp.com/
# 16  https://www.truefoodkitchen.com/locations/dall...
# 17  https://locations.bucadibeppo.com/us/tx/dallas...
# 18  https://www.seasons52.com/locations/tx/dallas/...
# 19  https://www.maggianos.com/locations/texas/dall...
# 20       http://www.konagrill.com/locations/dallas-tx
# 21                       http://www.thetacojoint.com/
# 22  https://www.nordstrom.com/store-details/nordst...
# 23  http://hillstonerestaurant.com/locations/dalla...
# 24  https://locations.thecheesecakefactory.com/tx/...
# 25                           https://www.elfenix.com/
# 26                      https://www.malaikitchen.com/
# 27                     http://www.muchachotexmex.com/
# 28                        http://gofishpoketexas.com/
# 29  https://roti.com/?utm_source=facebook&utm_medi...
# 30                        http://www.rexsseafood.com/
#
#                                 domain  \
# 0         locations.mcalistersdeli.com
# 1              landmarkrestodallas.com
# 2             locations.jimmyjohns.com
# 3               mychocolatesecrets.com
# 4                        starbucks.com
# 5                        starbucks.com
# 6                        starbucks.com
# 7                        pekersbar.com
# 8                 lalalandkindcafe.com
# 9                     mrmissterdtx.com
# 10                       jrsdallas.com
# 11                           sevys.com
# 12              ilbraccorestaurant.com
# 13                      rd-kitchen.com
# 14                       mlcdallas.com
# 15                   hudsonhousehp.com
# 16                 truefoodkitchen.com
# 17           locations.bucadibeppo.com
# 18                       seasons52.com
# 19                       maggianos.com
# 20                       konagrill.com
# 21                    thetacojoint.com
# 22                       nordstrom.com
# 23             hillstonerestaurant.com
# 24  locations.thecheesecakefactory.com
# 25                         elfenix.com
# 26                    malaikitchen.com
# 27                  muchachotexmex.com
# 28                 gofishpoketexas.com
# 29                            roti.com
# 30                     rexsseafood.com
#
#                         external_emails/0/value  \
# 0                     catering@shmcalisters.com
# 1                 info.dallas@warwickhotels.com
# 2                                           NaN
# 3                                           NaN
# 4             starbucks.gaesteservice@amrest.eu
# 5             starbucks.gaesteservice@amrest.eu
# 6             starbucks.gaesteservice@amrest.eu
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                        sevyscatering@aol.com
# 12                                          NaN
# 13                  guestservices@hillstone.com
# 14                                          NaN
# 15              careers@vandelayhospitality.com
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19  mg0218.roosevelt-generalmanager@brinker.com
# 20                               info@togrp.com
# 21                      jeffreykowitz@gmail.com
# 22                   ADAM.GORACKE@NORDSTROM.COM
# 23                  guestservices@hillstone.com
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                          NaN
#
#             external_emails/1/value   phones/0/value  phones/1/value  \
# 0   lakedelton.mcalisters@gmail.com      18148653869    1.701532e+10
# 1    sales.dallas@warwickhotels.com  +1 214-521-5151             NaN
# 2                               NaN              NaN             NaN
# 3                               NaN              NaN             NaN
# 4      ukinfo@support.starbucks.com              NaN             NaN
# 5      ukinfo@support.starbucks.com              NaN             NaN
# 6      ukinfo@support.starbucks.com              NaN             NaN
# 7                               NaN              NaN             NaN
# 8                               NaN              NaN             NaN
# 9                               NaN              NaN             NaN
# 10                              NaN             1200             NaN
# 11                              NaN              NaN             NaN
# 12                              NaN  +1 214-361-0100             NaN
# 13            hillstone@buyatab.com       8002309787    3.103953e+09
# 14                              NaN              NaN             NaN
# 15                              NaN       2145832255    2.147025e+09
# 16                              NaN       6027743488    4.802654e+09
# 17                              NaN      17045425146    1.877955e+10
# 18                              NaN              NaN             NaN
# 19            mg0219del@brinker.com              NaN             NaN
# 20            Dempsey@konagrill.Com              NaN             NaN
# 21            tacojointlw@gmail.com              NaN             NaN
# 22     ADAM.MCCASLAND@NORDSTROM.COM              NaN             NaN
# 23            hillstone@buyatab.com       8002309787    3.055290e+09
# 24                              NaN              NaN             NaN
# 25                              NaN  +1 214-747-1121             NaN
# 26                              NaN              NaN             NaN
# 27                              NaN       4695132944    6.824774e+09
# 28                              NaN              NaN             NaN
# 29                              NaN              NaN             NaN
# 30                              NaN      12147580566    1.214273e+10
#
#     phones/2/value  phones/3/value   phones/4/value  phones/5/value  ...  \
# 0     1.307742e+10    1.608253e+10       6082530997    1.208964e+10  ...
# 1              NaN             NaN              NaN             NaN  ...
# 2              NaN             NaN              NaN             NaN  ...
# 3              NaN             NaN              NaN             NaN  ...
# 4              NaN             NaN              NaN             NaN  ...
# 5              NaN             NaN              NaN             NaN  ...
# 6              NaN             NaN              NaN             NaN  ...
# 7              NaN             NaN              NaN             NaN  ...
# 8              NaN             NaN              NaN             NaN  ...
# 9              NaN             NaN              NaN             NaN  ...
# 10             NaN             NaN              NaN             NaN  ...
# 11             NaN             NaN              NaN             NaN  ...
# 12             NaN             NaN              NaN             NaN  ...
# 13    9.492191e+09    1.888304e+10       7079450920    2.148908e+09  ...
# 14             NaN             NaN              NaN             NaN  ...
# 15    2.143633e+09             NaN              NaN             NaN  ...
# 16    6.027423e+09    4.802120e+09  +1 480-212-0175             NaN  ...
# 17    1.770644e+10    1.202233e+10      15058722822    1.502493e+10  ...
# 18             NaN             NaN              NaN             NaN  ...
# 19             NaN             NaN              NaN             NaN  ...
# 20             NaN             NaN              NaN             NaN  ...
# 21             NaN             NaN              NaN             NaN  ...
# 22             NaN             NaN              NaN             NaN  ...
# 23    3.105768e+09    2.146919e+09       7135292385    3.033335e+09  ...
# 24             NaN             NaN              NaN             NaN  ...
# 25             NaN             NaN              NaN             NaN  ...
# 26             NaN             NaN              NaN             NaN  ...
# 27             NaN             NaN              NaN             NaN  ...
# 28             NaN             NaN              NaN             NaN  ...
# 29             NaN             NaN              NaN             NaN  ...
# 30             NaN             NaN              NaN             NaN  ...
#
#     external_emails/1/full_name external_emails/1/title  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# 5                           NaN                     NaN
# 6                           NaN                     NaN
# 7                           NaN                     NaN
# 8                           NaN                     NaN
# 9                           NaN                     NaN
# 10                          NaN                     NaN
# 11                          NaN                     NaN
# 12                          NaN                     NaN
# 13                          NaN                     NaN
# 14                          NaN                     NaN
# 15                          NaN                     NaN
# 16                          NaN                     NaN
# 17                          NaN                     NaN
# 18                          NaN                     NaN
# 19                          NaN                     NaN
# 20               Donald Dempsey                     NaN
# 21                          NaN                     NaN
# 22              Adam  Mccasland                     NaN
# 23                          NaN                     NaN
# 24                          NaN                     NaN
# 25                          NaN                     NaN
# 26                          NaN                     NaN
# 27                          NaN                     NaN
# 28                          NaN                     NaN
# 29                          NaN                     NaN
# 30                          NaN                     NaN
#
#    external_emails/2/full_name external_emails/2/title emails/0/full_name  \
# 0                          NaN                     NaN                NaN
# 1                          NaN                     NaN                NaN
# 2                          NaN                     NaN                NaN
# 3                          NaN                     NaN                NaN
# 